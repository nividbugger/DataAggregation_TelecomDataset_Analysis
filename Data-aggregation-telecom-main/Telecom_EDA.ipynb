# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('bus_B_longlat_csv.csv')

#pd.read_csv('bus_A_longlat.xlsx', sep='|', encoding='latin-1')

# %%
df.head()
BBox=(df.Longitude.min(), df.Longitude.max(), df.Latitude.min(), df.Latitude.max())
print(df.Longitude.min())
print(df.Longitude.max())
print(df.Latitude.min())
print(df.Latitude.max())
# Out:
# -8.505954
# -8.45585
# 51.883072999999996
# 51.915853000000006

# %%
ruh_m = plt.imread('bus_b.png')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df.Longitude, df.Latitude, zorder=1, alpha= 0.1, c='r', s=10)
ax.set_title('Plotting Spatial Data on Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('bus_A_longlat_csv.csv')

# %%
df.head()
BBox=(df.Longitude.min(), df.Longitude.max(), df.Latitude.min(), df.Latitude.max())
print(df.Longitude.min())
print(df.Longitude.max())
print(df.Latitude.min())
print(df.Latitude.max())

# %%
ruh_m = plt.imread('bus_a_crop.png')

# %%
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df.Longitude, df.Latitude, zorder=1, alpha= 0.1, c='b', s=10)
ax.set_title('Plotting Spatial Data on Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('car_A.csv')

# %%
#df['Longitude'] = df['Longitude'].astype(float, copy=True)
#df["Longitude"] = pd.to_numeric(df["Longitude"], downcast="float")

# %%
df.head()
BBox=(df.Longitude.min(), df.Longitude.max(), df.Latitude.min(), df.Latitude.max())
print(df.Longitude.min())
print(df.Longitude.max())
print(df.Latitude.min())
print(df.Latitude.max())
# Out:
# -8.388084
# Longitude
# 51.871394
# Latitude
